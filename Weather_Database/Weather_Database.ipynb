# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %%
# Create an empty list 
city_data = []

# %%
# Access the Weather API
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | sokolka
# Processing Record 6 of Set 1 | cavalcante
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | sur
# Processing Record 11 of Set 1 | san luis
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | hastings
# Processing Record 17 of Set 1 | tezu
# Processing Record 18 of Set 1 | garmsar
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | ishigaki
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | yining
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | bria
# Processing Record 29 of Set 1 | dourbali
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | half moon bay
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | palm coast
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | sakakah
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | vanimo
# Processing Record 41 of Set 1 | zhigansk
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | dekoa
# City not found. Skipping...
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | talnakh
# Processing Record 46 of Set 1 | tubmanburg
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 2 | nuuk
# Processing Record 4 of Set 2 | tagusao
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | kitimat
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | veraval
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | ulladulla
# Processing Record 12 of Set 2 | pacific grove
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | tessalit
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 2 | kholodnyy
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | flinders
# Processing Record 23 of Set 2 | conceicao do araguaia
# Processing Record 24 of Set 2 | sosandra
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | svetlogorsk
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | muros
# Processing Record 33 of Set 2 | saint-pierre
# Processing Record 34 of Set 2 | shelburne
# Processing Record 35 of Set 2 | grafton
# Processing Record 36 of Set 2 | araouane
# Processing Record 37 of Set 2 | kigoma
# Processing Record 38 of Set 2 | caernarfon
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | belaya gora
# Processing Record 43 of Set 2 | jining
# Processing Record 44 of Set 2 | todos santos
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | tutoia
# Processing Record 47 of Set 2 | middelburg
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | kununurra
# Processing Record 50 of Set 2 | kuusamo
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | porto recanati
# Processing Record 3 of Set 3 | samarai
# Processing Record 4 of Set 3 | bonavista
# Processing Record 5 of Set 3 | voi
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | yar-sale
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | puerto colombia
# Processing Record 10 of Set 3 | hetauda
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | dunedin
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | kibara
# Processing Record 15 of Set 3 | bereda
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | airai
# Processing Record 18 of Set 3 | sorong
# Processing Record 19 of Set 3 | buenos aires
# Processing Record 20 of Set 3 | dukat
# Processing Record 21 of Set 3 | aviles
# Processing Record 22 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 23 of Set 3 | junagadh
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | kailua
# Processing Record 26 of Set 3 | vanavara
# Processing Record 27 of Set 3 | alice springs
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | pafos
# Processing Record 30 of Set 3 | itarema
# Processing Record 31 of Set 3 | payo
# Processing Record 32 of Set 3 | cibitoke
# Processing Record 33 of Set 3 | san vicente
# Processing Record 34 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 35 of Set 3 | syasstroy
# Processing Record 36 of Set 3 | fomboni
# Processing Record 37 of Set 3 | jeremie
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | bibiani
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | miranda de ebro
# Processing Record 44 of Set 3 | thinadhoo
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | bollnas
# Processing Record 47 of Set 3 | avera
# Processing Record 48 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 3 | xining
# Processing Record 50 of Set 3 | hualmay
# Processing Record 1 of Set 4 | itoman
# Processing Record 2 of Set 4 | namatanai
# Processing Record 3 of Set 4 | luderitz
# Processing Record 4 of Set 4 | abu samrah
# Processing Record 5 of Set 4 | san quintin
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | cape town
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 4 | gumdag
# Processing Record 11 of Set 4 | faya
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | ponta delgada
# Processing Record 14 of Set 4 | bar harbor
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | ngunguru
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | kincardine
# Processing Record 19 of Set 4 | oltu
# Processing Record 20 of Set 4 | guerrero negro
# Processing Record 21 of Set 4 | ca mau
# Processing Record 22 of Set 4 | broome
# Processing Record 23 of Set 4 | eyrarbakki
# Processing Record 24 of Set 4 | punta gorda
# Processing Record 25 of Set 4 | urubamba
# Processing Record 26 of Set 4 | severobaykalsk
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 4 | upernavik
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | leh
# Processing Record 33 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | gloversville
# Processing Record 36 of Set 4 | quchan
# Processing Record 37 of Set 4 | islamkot
# Processing Record 38 of Set 4 | yankton
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | bafra
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | kiama
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | rolla
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | buraydah
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | saldanha
# Processing Record 1 of Set 5 | tautira
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | coahuayana
# Processing Record 4 of Set 5 | sanford
# Processing Record 5 of Set 5 | jamkhed
# Processing Record 6 of Set 5 | acapulco
# Processing Record 7 of Set 5 | port macquarie
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | mareeba
# Processing Record 10 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | russell
# Processing Record 13 of Set 5 | sechura
# Processing Record 14 of Set 5 | yatou
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | joshimath
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | bambous virieux
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | manavalakurichi
# Processing Record 22 of Set 5 | alta floresta
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | saint-augustin
# Processing Record 25 of Set 5 | ak-dovurak
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | gamba
# Processing Record 28 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 29 of Set 5 | milkovo
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | ostersund
# Processing Record 33 of Set 5 | inndyr
# Processing Record 34 of Set 5 | pskov
# Processing Record 35 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 5 | mahebourg
# Processing Record 37 of Set 5 | tazovskiy
# Processing Record 38 of Set 5 | east london
# Processing Record 39 of Set 5 | porto velho
# Processing Record 40 of Set 5 | kande
# Processing Record 41 of Set 5 | moindou
# Processing Record 42 of Set 5 | monrovia
# Processing Record 43 of Set 5 | santa cruz de la palma
# Processing Record 44 of Set 5 | batemans bay
# Processing Record 45 of Set 5 | sarangani
# Processing Record 46 of Set 5 | urengoy
# Processing Record 47 of Set 5 | barabinsk
# Processing Record 48 of Set 5 | safford
# Processing Record 49 of Set 5 | morant bay
# Processing Record 50 of Set 5 | calama
# Processing Record 1 of Set 6 | puerto rondon
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | izberbash
# Processing Record 4 of Set 6 | turka
# Processing Record 5 of Set 6 | tomatlan
# Processing Record 6 of Set 6 | kipini
# Processing Record 7 of Set 6 | atar
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | faanui
# Processing Record 10 of Set 6 | general roca
# Processing Record 11 of Set 6 | katsuura
# Processing Record 12 of Set 6 | jesup
# Processing Record 13 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 6 | mao
# Processing Record 15 of Set 6 | otradnoye
# Processing Record 16 of Set 6 | sai buri
# Processing Record 17 of Set 6 | provideniya
# Processing Record 18 of Set 6 | derzhavinsk
# Processing Record 19 of Set 6 | vardo
# Processing Record 20 of Set 6 | bridgetown
# Processing Record 21 of Set 6 | puerto narino
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | aschaffenburg
# Processing Record 24 of Set 6 | burnie
# Processing Record 25 of Set 6 | kawalu
# Processing Record 26 of Set 6 | tuatapere
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | gushikawa
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | makakilo city
# Processing Record 31 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 6 | skawina
# Processing Record 33 of Set 6 | matiguas
# Processing Record 34 of Set 6 | massaguet
# Processing Record 35 of Set 6 | severo-kurilsk
# Processing Record 36 of Set 6 | farmers branch
# Processing Record 37 of Set 6 | el tigre
# Processing Record 38 of Set 6 | rio grande
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 6 | limon
# Processing Record 42 of Set 6 | mehamn
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | ixtapa
# Processing Record 45 of Set 6 | hovd
# Processing Record 46 of Set 6 | birjand
# Processing Record 47 of Set 6 | spring valley
# Processing Record 48 of Set 6 | buchanan
# Processing Record 49 of Set 6 | goias
# Processing Record 50 of Set 6 | pisco
# Processing Record 1 of Set 7 | carbonia
# Processing Record 2 of Set 7 | puerto madryn
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | chuy
# Processing Record 5 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 7 | careiro da varzea
# Processing Record 7 of Set 7 | gwadar
# Processing Record 8 of Set 7 | muscatine
# Processing Record 9 of Set 7 | kristiinankaupunki
# Processing Record 10 of Set 7 | henties bay
# Processing Record 11 of Set 7 | teguise
# Processing Record 12 of Set 7 | shenjiamen
# Processing Record 13 of Set 7 | strezhevoy
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | nishihara
# Processing Record 17 of Set 7 | wabash
# Processing Record 18 of Set 7 | baykit
# Processing Record 19 of Set 7 | ouegoa
# Processing Record 20 of Set 7 | raduzhnyy
# Processing Record 21 of Set 7 | valparaiso
# Processing Record 22 of Set 7 | bonthe
# Processing Record 23 of Set 7 | macia
# Processing Record 24 of Set 7 | husavik
# Processing Record 25 of Set 7 | isabela
# Processing Record 26 of Set 7 | millerovo
# Processing Record 27 of Set 7 | popondetta
# Processing Record 28 of Set 7 | svetlyy
# Processing Record 29 of Set 7 | khatanga
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | yeppoon
# Processing Record 32 of Set 7 | esfarayen
# Processing Record 33 of Set 7 | geraldton
# Processing Record 34 of Set 7 | singaparna
# Processing Record 35 of Set 7 | luocheng
# Processing Record 36 of Set 7 | sistranda
# Processing Record 37 of Set 7 | camacha
# Processing Record 38 of Set 7 | sulya
# Processing Record 39 of Set 7 | khash
# Processing Record 40 of Set 7 | marsa matruh
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | tambo
# Processing Record 43 of Set 7 | merauke
# Processing Record 44 of Set 7 | englehart
# Processing Record 45 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 7 | lavrentiya
# Processing Record 47 of Set 7 | aguililla
# Processing Record 48 of Set 7 | panjab
# Processing Record 49 of Set 7 | dali
# Processing Record 50 of Set 7 | kologriv
# Processing Record 1 of Set 8 | bafq
# Processing Record 2 of Set 8 | lazaro cardenas
# Processing Record 3 of Set 8 | puerto escondido
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | alofi
# Processing Record 6 of Set 8 | krasnoselkup
# Processing Record 7 of Set 8 | araceli
# Processing Record 8 of Set 8 | nelson bay
# Processing Record 9 of Set 8 | victor harbor
# Processing Record 10 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 8 | kavaratti
# Processing Record 12 of Set 8 | beloha
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | outjo
# Processing Record 15 of Set 8 | vila velha
# Processing Record 16 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | whitehorse
# Processing Record 19 of Set 8 | bengkulu
# Processing Record 20 of Set 8 | bathsheba
# Processing Record 21 of Set 8 | comarapa
# Processing Record 22 of Set 8 | esperance
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | karachi
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | arman
# Processing Record 28 of Set 8 | aklavik
# Processing Record 29 of Set 8 | koumac
# Processing Record 30 of Set 8 | patti
# Processing Record 31 of Set 8 | mumford
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | acarau
# Processing Record 34 of Set 8 | mafinga
# Processing Record 35 of Set 8 | port blair
# Processing Record 36 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 8 | murgab
# Processing Record 38 of Set 8 | ulcinj
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | koungou
# Processing Record 41 of Set 8 | papara
# Processing Record 42 of Set 8 | bilma
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | lata
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | balkanabat
# Processing Record 47 of Set 8 | bulgan
# Processing Record 48 of Set 8 | kolokani
# Processing Record 49 of Set 8 | roald
# Processing Record 50 of Set 8 | sinnamary
# Processing Record 1 of Set 9 | redwater
# Processing Record 2 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 3 of Set 9 | vestmanna
# Processing Record 4 of Set 9 | qasigiannguit
# Processing Record 5 of Set 9 | plouzane
# Processing Record 6 of Set 9 | ucluelet
# Processing Record 7 of Set 9 | khasan
# Processing Record 8 of Set 9 | havre-saint-pierre
# Processing Record 9 of Set 9 | edd
# Processing Record 10 of Set 9 | skjervoy
# Processing Record 11 of Set 9 | junin
# Processing Record 12 of Set 9 | makurdi
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | brae
# Processing Record 15 of Set 9 | acajutla
# Processing Record 16 of Set 9 | prado
# Processing Record 17 of Set 9 | tara
# Processing Record 18 of Set 9 | nouadhibou
# Processing Record 19 of Set 9 | stornoway
# Processing Record 20 of Set 9 | baturaja
# Processing Record 21 of Set 9 | shunyi
# Processing Record 22 of Set 9 | guanica
# Processing Record 23 of Set 9 | mocuba
# Processing Record 24 of Set 9 | witu
# Processing Record 25 of Set 9 | ostrovnoy
# Processing Record 26 of Set 9 | yerbogachen
# Processing Record 27 of Set 9 | buarcos
# Processing Record 28 of Set 9 | cabo san lucas
# Processing Record 29 of Set 9 | natal
# Processing Record 30 of Set 9 | warrensburg
# Processing Record 31 of Set 9 | siwan
# Processing Record 32 of Set 9 | turukhansk
# Processing Record 33 of Set 9 | gaspe
# Processing Record 34 of Set 9 | rodrigues alves
# Processing Record 35 of Set 9 | port augusta
# Processing Record 36 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | ayan
# Processing Record 39 of Set 9 | dzaoudzi
# Processing Record 40 of Set 9 | mitha tiwana
# Processing Record 41 of Set 9 | asfi
# Processing Record 42 of Set 9 | kendari
# Processing Record 43 of Set 9 | cukai
# Processing Record 44 of Set 9 | coffs harbour
# Processing Record 45 of Set 9 | krasnyy chikoy
# Processing Record 46 of Set 9 | hami
# Processing Record 47 of Set 9 | kirando
# Processing Record 48 of Set 9 | pacifica
# Processing Record 49 of Set 9 | ligayan
# Processing Record 50 of Set 9 | campbell river
# Processing Record 1 of Set 10 | yucca valley
# Processing Record 2 of Set 10 | verkhoyansk
# Processing Record 3 of Set 10 | jacareacanga
# Processing Record 4 of Set 10 | challapata
# Processing Record 5 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | namie
# Processing Record 8 of Set 10 | khorinsk
# Processing Record 9 of Set 10 | nouakchott
# Processing Record 10 of Set 10 | gao
# Processing Record 11 of Set 10 | nizhniy chir
# Processing Record 12 of Set 10 | launceston
# Processing Record 13 of Set 10 | inverbervie
# Processing Record 14 of Set 10 | dalby
# Processing Record 15 of Set 10 | lubango
# Processing Record 16 of Set 10 | xichang
# Processing Record 17 of Set 10 | demirci
# Processing Record 18 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 10 | luau
# Processing Record 20 of Set 10 | formosa
# Processing Record 21 of Set 10 | udachnyy
# Processing Record 22 of Set 10 | dogbo
# Processing Record 23 of Set 10 | lodja
# Processing Record 24 of Set 10 | sisimiut
# Processing Record 25 of Set 10 | trelew
# Processing Record 26 of Set 10 | te anau
# Processing Record 27 of Set 10 | college
# Processing Record 28 of Set 10 | marquette
# Processing Record 29 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 10 | poum
# Processing Record 31 of Set 10 | cadillac
# Processing Record 32 of Set 10 | cleveland
# Processing Record 33 of Set 10 | banda aceh
# Processing Record 34 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 35 of Set 10 | khandyga
# Processing Record 36 of Set 10 | moussoro
# Processing Record 37 of Set 10 | deputatskiy
# Processing Record 38 of Set 10 | grindavik
# Processing Record 39 of Set 10 | saint-georges
# Processing Record 40 of Set 10 | altay
# Processing Record 41 of Set 10 | wanning
# Processing Record 42 of Set 10 | terrace bay
# Processing Record 43 of Set 10 | gimli
# Processing Record 44 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 10 | praia da vitoria
# Processing Record 46 of Set 10 | orotukan
# Processing Record 47 of Set 10 | sonoita
# Processing Record 48 of Set 10 | madawaska
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | svobodnyy
# Processing Record 1 of Set 11 | castanos
# Processing Record 2 of Set 11 | obo
# Processing Record 3 of Set 11 | mayumba
# Processing Record 4 of Set 11 | tabou
# Processing Record 5 of Set 11 | brindisi
# Processing Record 6 of Set 11 | hinton
# Processing Record 7 of Set 11 | zhanakorgan
# Processing Record 8 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 11 | batsfjord
# Processing Record 10 of Set 11 | orangeburg
# Processing Record 11 of Set 11 | meadow lake
# Processing Record 12 of Set 11 | solnechnyy
# Processing Record 13 of Set 11 | grand gaube
# Processing Record 14 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 11 | richards bay
# Processing Record 16 of Set 11 | tasiilaq
# Processing Record 17 of Set 11 | ormara
# Processing Record 18 of Set 11 | yarim
# Processing Record 19 of Set 11 | elliot lake
# Processing Record 20 of Set 11 | yendi
# Processing Record 21 of Set 11 | gat
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | yulara
# Processing Record 24 of Set 11 | kutum
# Processing Record 25 of Set 11 | alamogordo
# Processing Record 26 of Set 11 | boli
# Processing Record 27 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 11 | chicama
# Processing Record 29 of Set 11 | egvekinot
# Processing Record 30 of Set 11 | domna
# Processing Record 31 of Set 11 | kotka
# Processing Record 32 of Set 11 | hazorasp
# Processing Record 33 of Set 11 | chaochou
# City not found. Skipping...
# Processing Record 34 of Set 11 | douentza
# Processing Record 35 of Set 11 | kamenka
# Processing Record 36 of Set 11 | ouro preto do oeste
# Processing Record 37 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | harnosand
# Processing Record 40 of Set 11 | san patricio
# Processing Record 41 of Set 11 | lorengau
# Processing Record 42 of Set 11 | salto
# Processing Record 43 of Set 11 | koppies
# Processing Record 44 of Set 11 | maues
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 11 | ossora
# Processing Record 48 of Set 11 | tanete
# Processing Record 49 of Set 11 | vagay
# Processing Record 50 of Set 11 | oussouye
# Processing Record 1 of Set 12 | sao filipe
# Processing Record 2 of Set 12 | wenling
# Processing Record 3 of Set 12 | nezhinka
# Processing Record 4 of Set 12 | arcata
# Processing Record 5 of Set 12 | salamiyah
# Processing Record 6 of Set 12 | lashio
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | rach gia
# Processing Record 9 of Set 12 | amga
# Processing Record 10 of Set 12 | aykhal
# Processing Record 11 of Set 12 | sorland
# Processing Record 12 of Set 12 | port antonio
# Processing Record 13 of Set 12 | los negros
# Processing Record 14 of Set 12 | bayangol
# Processing Record 15 of Set 12 | lebu
# Processing Record 16 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 12 | kopavogur
# Processing Record 18 of Set 12 | portland
# Processing Record 19 of Set 12 | kenai
# Processing Record 20 of Set 12 | moranbah
# Processing Record 21 of Set 12 | inongo
# Processing Record 22 of Set 12 | santa catalina
# Processing Record 23 of Set 12 | mount isa
# Processing Record 24 of Set 12 | marsh harbour
# Processing Record 25 of Set 12 | manggar
# Processing Record 26 of Set 12 | acari
# Processing Record 27 of Set 12 | halifax
# Processing Record 28 of Set 12 | jermuk
# Processing Record 29 of Set 12 | storforshei
# Processing Record 30 of Set 12 | coquimbo
# Processing Record 31 of Set 12 | kadiri
# Processing Record 32 of Set 12 | grand-lahou
# Processing Record 33 of Set 12 | ambon
# Processing Record 34 of Set 12 | marienburg
# Processing Record 35 of Set 12 | mananjary
# Processing Record 36 of Set 12 | shache
# Processing Record 37 of Set 12 | rawson
# Processing Record 38 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 12 | camargo
# Processing Record 40 of Set 12 | jiangkou
# Processing Record 41 of Set 12 | atherton
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | mount gambier
# Processing Record 44 of Set 12 | miri
# Processing Record 45 of Set 12 | sibolga
# Processing Record 46 of Set 12 | barcelos
# Processing Record 47 of Set 12 | berlevag
# Processing Record 48 of Set 12 | sikonge
# Processing Record 49 of Set 12 | nalbari
# Processing Record 50 of Set 12 | dongsheng
# Processing Record 1 of Set 13 | mitsamiouli
# Processing Record 2 of Set 13 | susanville
# Processing Record 3 of Set 13 | chone
# Processing Record 4 of Set 13 | honiara
# Processing Record 5 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 7 of Set 13 | oksovskiy
# Processing Record 8 of Set 13 | kandrian
# Processing Record 9 of Set 13 | shingu
# Processing Record 10 of Set 13 | los llanos de aridane
# Processing Record 11 of Set 13 | kalianget
# Processing Record 12 of Set 13 | erdenet
# Processing Record 13 of Set 13 | wanaka
# Processing Record 14 of Set 13 | liverpool
# Processing Record 15 of Set 13 | sao joao da barra
# Processing Record 16 of Set 13 | zelenogorskiy
# Processing Record 17 of Set 13 | sompeta
# Processing Record 18 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 19 of Set 13 | aswan
# Processing Record 20 of Set 13 | san juan
# Processing Record 21 of Set 13 | tateyama
# Processing Record 22 of Set 13 | kirakira
# Processing Record 23 of Set 13 | padang
# Processing Record 24 of Set 13 | zhangye
# Processing Record 25 of Set 13 | willowmore
# Processing Record 26 of Set 13 | luganville
# Processing Record 27 of Set 13 | marbella
# Processing Record 28 of Set 13 | sohag
# Processing Record 29 of Set 13 | mogzon
# Processing Record 30 of Set 13 | salvador
# Processing Record 31 of Set 13 | calvinia
# Processing Record 32 of Set 13 | rocha
# Processing Record 33 of Set 13 | karaton
# Processing Record 34 of Set 13 | sorsk
# Processing Record 35 of Set 13 | urumqi
# Processing Record 36 of Set 13 | wagar
# Processing Record 37 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 13 | paita
# Processing Record 39 of Set 13 | nara
# Processing Record 40 of Set 13 | port hedland
# Processing Record 41 of Set 13 | fukue
# Processing Record 42 of Set 13 | kodiak
# Processing Record 43 of Set 13 | karasburg
# Processing Record 44 of Set 13 | puerto leguizamo
# Processing Record 45 of Set 13 | bandarbeyla
# Processing Record 46 of Set 13 | kefar tavor
# Processing Record 47 of Set 13 | lafiagi
# Processing Record 48 of Set 13 | christchurch
# Processing Record 49 of Set 13 | kupino
# Processing Record 50 of Set 13 | seydi
# Processing Record 1 of Set 14 | quatre cocos
# Processing Record 2 of Set 14 | laguna
# Processing Record 3 of Set 14 | cogoleto
# Processing Record 4 of Set 14 | chauk
# Processing Record 5 of Set 14 | kushiro
# Processing Record 6 of Set 14 | treinta y tres
# Processing Record 7 of Set 14 | rafaela
# Processing Record 8 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 9 of Set 14 | trowbridge
# Processing Record 10 of Set 14 | sola
# Processing Record 11 of Set 14 | winnemucca
# Processing Record 12 of Set 14 | klaksvik
# Processing Record 13 of Set 14 | mpika
# Processing Record 14 of Set 14 | slave lake
# Processing Record 15 of Set 14 | jalingo
# Processing Record 16 of Set 14 | lukuledi
# Processing Record 17 of Set 14 | omsukchan
# Processing Record 18 of Set 14 | mogoytuy
# Processing Record 19 of Set 14 | narsaq
# Processing Record 20 of Set 14 | isiolo
# Processing Record 21 of Set 14 | dabat
# Processing Record 22 of Set 14 | akyab
# Processing Record 23 of Set 14 | cabatuan
# Processing Record 24 of Set 14 | the valley
# Processing Record 25 of Set 14 | novyy urengoy
# Processing Record 26 of Set 14 | krechevitsy
# Processing Record 27 of Set 14 | jequie
# Processing Record 28 of Set 14 | myitkyina
# Processing Record 29 of Set 14 | moscow
# Processing Record 30 of Set 14 | bridlington
# Processing Record 31 of Set 14 | slavgorod
# Processing Record 32 of Set 14 | ilulissat
# Processing Record 33 of Set 14 | trincomalee
# Processing Record 34 of Set 14 | fortuna foothills
# Processing Record 35 of Set 14 | jieshi
# Processing Record 36 of Set 14 | rovaniemi
# Processing Record 37 of Set 14 | bara
# Processing Record 38 of Set 14 | port-cartier
# Processing Record 39 of Set 14 | lumphat
# Processing Record 40 of Set 14 | riyadh
# Processing Record 41 of Set 14 | teguldet
# Processing Record 42 of Set 14 | kita
# Processing Record 43 of Set 14 | paamiut
# Processing Record 44 of Set 14 | borken
# Processing Record 45 of Set 14 | walvis bay
# Processing Record 46 of Set 14 | bakel
# Processing Record 47 of Set 14 | jalu
# Processing Record 48 of Set 14 | tecoanapa
# Processing Record 49 of Set 14 | sabang
# Processing Record 50 of Set 14 | changde
# Processing Record 1 of Set 15 | marystown
# Processing Record 2 of Set 15 | harindanga
# Processing Record 3 of Set 15 | noshiro
# Processing Record 4 of Set 15 | miranda
# Processing Record 5 of Set 15 | san andres
# Processing Record 6 of Set 15 | misratah
# Processing Record 7 of Set 15 | zaoyang
# Processing Record 8 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 9 of Set 15 | bairiki
# Processing Record 10 of Set 15 | sento se
# City not found. Skipping...
# Processing Record 11 of Set 15 | bolshoy uluy
# City not found. Skipping...
# Processing Record 12 of Set 15 | kudahuvadhoo
# Processing Record 13 of Set 15 | biloela
# Processing Record 14 of Set 15 | nueva loja
# Processing Record 15 of Set 15 | comodoro rivadavia
# Processing Record 16 of Set 15 | molina
# Processing Record 17 of Set 15 | belawan
# Processing Record 18 of Set 15 | belomorsk
# Processing Record 19 of Set 15 | knin
# Processing Record 20 of Set 15 | la romana
# Processing Record 21 of Set 15 | natchitoches
# Processing Record 22 of Set 15 | omboue
# Processing Record 23 of Set 15 | kumi
# Processing Record 24 of Set 15 | narasannapeta
# Processing Record 25 of Set 15 | phangnga
# Processing Record 26 of Set 15 | cabedelo
# Processing Record 27 of Set 15 | sambava
# Processing Record 28 of Set 15 | komsomolskiy
# Processing Record 29 of Set 15 | bull savanna
# Processing Record 30 of Set 15 | buala
# Processing Record 31 of Set 15 | hongan
# City not found. Skipping...
# Processing Record 32 of Set 15 | kysyl-syr
# Processing Record 33 of Set 15 | coruripe
# Processing Record 34 of Set 15 | manta
# Processing Record 35 of Set 15 | byron bay
# Processing Record 36 of Set 15 | navolato
# Processing Record 37 of Set 15 | luanda
# Processing Record 38 of Set 15 | cilegon
# Processing Record 39 of Set 15 | darien
# Processing Record 40 of Set 15 | umm lajj
# Processing Record 41 of Set 15 | angoche
# Processing Record 42 of Set 15 | qiryat gat
# Processing Record 43 of Set 15 | qui nhon
# Processing Record 44 of Set 15 | kloulklubed
# Processing Record 45 of Set 15 | dwarka
# Processing Record 46 of Set 15 | mahina
# Processing Record 47 of Set 15 | mackay
# Processing Record 48 of Set 15 | vangaindrano
# Processing Record 49 of Set 15 | qaqortoq
# Processing Record 50 of Set 15 | nadym
# Processing Record 1 of Set 16 | tahoua
# Processing Record 2 of Set 16 | lagoa
# Processing Record 3 of Set 16 | gizo
# Processing Record 4 of Set 16 | banamba
# Processing Record 5 of Set 16 | baldeogarh
# Processing Record 6 of Set 16 | bagdarin
# Processing Record 7 of Set 16 | glubokoe
# City not found. Skipping...
# Processing Record 8 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 16 | hobyo
# Processing Record 10 of Set 16 | ampanihy
# Processing Record 11 of Set 16 | yaan
# Processing Record 12 of Set 16 | puerto del rosario
# Processing Record 13 of Set 16 | mayo
# Processing Record 14 of Set 16 | inuvik
# Processing Record 15 of Set 16 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 16 | ahuimanu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Arraial Do Cabo -22.9661  -42.0278     78.76        83          20
# 1             Jamestown  42.0970  -79.2353     36.72       100          90
# 2                Atuona  -9.8000 -139.0333     78.33        74           1
# 3               Sokolka  53.4072   23.5023     35.38        97         100
# 4            Cavalcante -13.7975  -47.4583     77.94        73          32
# ..                  ...      ...       ...       ...       ...         ...
# 694                Yaan   7.3833    8.5667     81.73        31          90
# 695  Puerto Del Rosario  28.5004  -13.8627     65.95        63          20
# 696                Mayo  38.8876  -76.5119     57.24        57          60
# 697              Inuvik  68.3499 -133.7218    -11.99        77          75
# 698            Ahuimanu  21.4447 -157.8378     80.31        68          20
#
#      Wind Speed Country Current Description
# 0          6.91      BR          few clouds
# 1          9.22      US                snow
# 2         18.88      PF           clear sky
# 3          9.86      PL     overcast clouds
# 4          4.63      BR    scattered clouds
# ..          ...     ...                 ...
# 694        0.60      NG     overcast clouds
# 695       21.85      ES          few clouds
# 696        2.08      US       broken clouds
# 697       11.50      CA          light snow
# 698       12.66      US          few clouds
#
# [699 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     78.76        83          20
# 1        Jamestown      US  42.0970  -79.2353     36.72       100          90
# 2           Atuona      PF  -9.8000 -139.0333     78.33        74           1
# 3          Sokolka      PL  53.4072   23.5023     35.38        97         100
# 4       Cavalcante      BR -13.7975  -47.4583     77.94        73          32
# 5        Carnarvon      AU -24.8667  113.6333     75.27        64           0
# 6         Hermanus      ZA -34.4187   19.2345     64.36        83          62
# 7              Sur      OM  22.5667   59.5289     73.96        58           0
# 8         San Luis      AR -33.2950  -66.3356     75.61        19           0
# 9     Punta Arenas      CL -53.1500  -70.9167     50.11        62          75
#
#    Wind Speed Current Description
# 0        6.91          few clouds
# 1        9.22                snow
# 2       18.88           clear sky
# 3        9.86     overcast clouds
# 4        4.63    scattered clouds
# 5       14.97           clear sky
# 6        8.59       broken clouds
# 7        0.49           clear sky
# 8       16.24           clear sky
# 9       29.93          light rain

# %%
# Create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Explort the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
